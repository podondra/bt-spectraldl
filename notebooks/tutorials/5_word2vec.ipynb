# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.087246
# Nearest to first: settings, imperfections, forecasting, abstracts, purists, expansionism, ioannis, spills,
# Nearest to that: darby, stated, anaesthetic, accomplishing, shutout, returner, apec, easternmost,
# Nearest to the: tapioca, sol, aggregate, aureus, viz, phnom, chris, playful,
# Nearest to so: geographically, illegitimate, louie, liars, easter, scotus, choreographer, obstruction,
# Nearest to b: constitutive, negri, khmer, perpetrators, violent, hit, puff, orientations,
# Nearest to world: molarity, chapin, arians, transferred, vilas, equalized, sowed, hanoverian,
# Nearest to no: shipyard, rugrats, sanders, madeline, digestive, authoritarian, numerically, squaring,
# Nearest to s: valentinus, lied, intent, unjustly, cassiopeia, possibilities, behold, autonomous,
# Nearest to would: baralong, describe, hung, mortuary, grab, quadrilateral, replenished, curt,
# Nearest to but: box, ranking, spaniards, causa, coppersmith, vigesimal, achaea, husk,
# Nearest to two: deputy, ccp, mosque, crimp, lunda, cruiser, awaken, ironic,
# Nearest to at: dewan, establishes, tolerant, substantive, buccaneers, verifiable, majored, really,
# Nearest to one: en, talents, khalq, brad, among, kubitzki, look, refugees,
# Nearest to an: swear, proviso, pastiches, sumerians, lambdamoo, sacagawea, pity, ascribed,
# Nearest to their: thither, edmond, authoritarianism, mahor, preferably, fansite, devries, covens,
# Nearest to on: upwelling, plesiosaur, encroaching, queueing, eligibility, polyatomic, rattus, organising,
# Average loss at step 2000: 4.369402
# Average loss at step 4000: 3.866225
# Average loss at step 6000: 3.787628
# Average loss at step 8000: 3.689489
# Average loss at step 10000: 3.613720
# Nearest to first: durham, marischal, debauchery, purists, during, settings, second, following,
# Nearest to that: which, flip, this, it, renoir, predictability, but, who,
# Nearest to the: its, a, this, his, an, any, wirth, assailants,
# Nearest to so: sancti, if, geographically, scotus, louie, illegitimate, easter, eternity,
# Nearest to b: proclamation, d, puff, willughby, hit, cursed, booklets, deafness,
# Nearest to world: eddic, referenda, sowed, transferred, juices, tomorrowland, squarely, discusses,
# Nearest to no: squaring, subfield, cartography, rugrats, shipyard, glaser, adventist, regan,
# Nearest to s: his, duran, valentinus, and, lied, claiming, nonviolent, panspermia,
# Nearest to would: can, could, might, may, will, baralong, not, did,
# Nearest to but: exons, particularly, causa, it, unionism, that, spaniards, husk,
# Nearest to two: three, five, four, six, eight, seven, nine, zero,
# Nearest to at: on, in, by, before, laterally, from, lew, presumes,
# Nearest to one: two, three, six, four, seven, unauthorized, eight, sturgeon,
# Nearest to an: the, grantham, transgender, sulfate, patrice, chinatown, formalize, bard,
# Nearest to their: his, its, yoshi, covens, the, hector, definable, preferably,
# Nearest to on: from, at, in, rattus, by, deteriorating, psychoanalysis, despite,
# Average loss at step 12000: 3.605174
# Average loss at step 14000: 3.570439
# Average loss at step 16000: 3.410139
# Average loss at step 18000: 3.458156
# Average loss at step 20000: 3.537843
# Nearest to first: second, following, debauchery, durham, last, marischal, same, next,
# Nearest to that: which, but, this, also, when, archaea, predictability, what,
# Nearest to the: its, their, a, this, clos, an, his, assailants,
# Nearest to so: sancti, geographically, if, scotus, afterward, dominicans, illegitimate, louie,
# Nearest to b: d, booklets, deviations, physica, dore, ethnomusicology, polyphyletic, mattress,
# Nearest to world: eddic, referenda, united, sowed, tomorrowland, programmes, proclamations, discusses,
# Nearest to no: any, regan, cartography, subfield, squaring, marbury, examiner, there,
# Nearest to s: claiming, duran, sandbox, furnished, awful, belew, sellers, bf,
# Nearest to would: can, could, will, may, might, did, does, to,
# Nearest to but: is, however, and, since, that, though, was, diners,
# Nearest to two: five, three, four, six, one, eight, seven, zero,
# Nearest to at: in, on, before, from, purposely, lew, fullmetal, dirac,
# Nearest to one: two, four, three, seven, five, eight, six, nine,
# Nearest to an: the, chinatown, transgender, sulfate, witted, dilbert, healy, sacagawea,
# Nearest to their: his, its, the, her, some, you, yoshi, definable,
# Nearest to on: in, at, upon, incalculable, against, rattus, stockpile, deteriorating,
# Average loss at step 22000: 3.504731
# Average loss at step 24000: 3.485419
# Average loss at step 26000: 3.484759
# Average loss at step 28000: 3.481576
# Average loss at step 30000: 3.504359
# Nearest to first: second, last, following, durham, next, same, debauchery, kovacs,
# Nearest to that: which, what, this, where, but, scholars, because, jesu,
# Nearest to the: their, its, his, a, wirth, asb, clos, sammy,
# Nearest to so: afterward, if, sancta, sancti, geographically, dominicans, louie, acadian,
# Nearest to b: d, booklets, oxidase, polyphyletic, amortized, van, projection, las,
# Nearest to world: eddic, united, sowed, referenda, discusses, plaques, populous, proclamations,
# Nearest to no: any, a, there, regan, squaring, meritocratic, examiner, tsing,
# Nearest to s: his, warheads, biometric, buteo, duran, client, ifrcs, bf,
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Nearest to but: however, when, and, since, that, until, although, which,
# Nearest to two: four, five, three, one, six, seven, eight, nine,
# Nearest to at: in, on, during, near, johnstone, through, before, purposely,
# Nearest to one: two, seven, four, five, six, three, eight, nine,
# Nearest to an: chinatown, sulfate, exuberant, ligases, roost, dorsey, kolbin, velar,
# Nearest to their: its, his, the, her, some, our, these, veda,
# Nearest to on: in, upon, through, at, against, stockpile, malo, from,
# Average loss at step 32000: 3.502983
# Average loss at step 34000: 3.493028
# Average loss at step 36000: 3.461621
# Average loss at step 38000: 3.301194
# Average loss at step 40000: 3.429339
# Nearest to first: second, last, next, following, same, debauchery, lutheran, third,
# Nearest to that: which, what, this, sickness, where, because, who, however,
# Nearest to the: their, its, his, a, this, kurtosis, any, asb,
# Nearest to so: sancti, afterward, geographically, dominicans, sancta, louie, acadian, if,
# Nearest to b: d, c, booklets, UNK, x, r, e, projection,
# Nearest to world: eddic, plaques, tomorrowland, populous, proclamations, referenda, sowed, temps,
# Nearest to no: any, regan, a, generally, ever, there, still, tsing,
# Nearest to s: his, and, forestall, biometric, imitative, cameroun, valentinus, generalisations,
# Nearest to would: could, will, can, may, might, did, must, should,
# Nearest to but: however, though, although, and, it, when, moons, did,
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to at: on, in, during, modalities, revue, dive, valiente, throughout,
# Nearest to one: four, seven, eight, two, six, five, nine, three,
# Nearest to an: transgender, exuberant, sulfate, chinatown, lice, dilbert, susima, secularism,
# Nearest to their: its, his, her, the, both, some, them, many,
# Nearest to on: upon, in, at, during, within, inevitable, konqueror, through,
# Average loss at step 42000: 3.436566
# Average loss at step 44000: 3.454954
# Average loss at step 46000: 3.447469
# Average loss at step 48000: 3.355054
# Average loss at step 50000: 3.386883
# Nearest to first: second, next, last, same, third, following, potencies, cricketers,
# Nearest to that: which, however, what, where, but, because, archaea, this,
# Nearest to the: its, this, their, any, his, a, some, these,
# Nearest to so: if, acadian, geographically, rocked, bullet, dominicans, rit, thus,
# Nearest to b: d, r, c, x, f, booklets, cardamom, takeover,
# Nearest to world: eddic, plaques, fante, tomorrowland, mays, carbides, sowed, covent,
# Nearest to no: any, regan, tsing, a, little, now, ever, salisbury,
# Nearest to s: biometric, whose, cameroun, duran, naming, his, was, bf,
# Nearest to would: will, could, can, may, might, should, must, did,
# Nearest to but: however, and, though, although, while, when, since, or,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to at: during, in, on, unto, rabid, from, polos, includes,
# Nearest to one: six, two, eight, seven, four, three, five, nine,
# Nearest to an: dilbert, velar, sacagawea, transgender, crystalline, chinatown, payroll, timor,
# Nearest to their: his, its, her, the, your, some, many, both,
# Nearest to on: upon, in, through, inevitable, at, about, during, throughout,
# Average loss at step 52000: 3.434868
# Average loss at step 54000: 3.425328
# Average loss at step 56000: 3.442289
# Average loss at step 58000: 3.397668
# Average loss at step 60000: 3.391080
# Nearest to first: second, last, next, same, following, third, scholastic, only,
# Nearest to that: which, what, this, predictability, however, where, archaea, it,
# Nearest to the: its, their, a, this, some, carburetor, his, each,
# Nearest to so: geographically, if, too, bullet, rocked, sancti, pump, afterward,
# Nearest to b: d, c, r, x, n, manitoba, cardamom, e,
# Nearest to world: eddic, referenda, mueller, covent, fante, tomorrowland, sowed, zealand,
# Nearest to no: any, regan, tsing, ever, little, fortress, meritocratic, abolishment,
# Nearest to s: turboprops, euskal, feasts, whose, valentinus, beelzebub, buteo, covertly,
# Nearest to would: will, could, may, can, might, must, should, does,
# Nearest to but: however, although, and, though, or, than, since, is,
# Nearest to two: three, four, six, five, one, eight, seven, nine,
# Nearest to at: during, in, before, centrioles, near, libi, hispanics, rabid,
# Nearest to one: six, two, four, seven, eight, five, nine, three,
# Nearest to an: transgender, idolatry, diagnoses, lice, src, ligases, payroll, dilbert,
# Nearest to their: its, his, her, the, your, whose, my, some,
# Nearest to on: upon, within, through, against, in, inevitable, reveal, stockpile,
# Average loss at step 62000: 3.239615
# Average loss at step 64000: 3.254881
# Average loss at step 66000: 3.404638
# Average loss at step 68000: 3.394584
# Average loss at step 70000: 3.365846
# Nearest to first: second, last, next, same, third, final, original, potencies,
# Nearest to that: which, however, what, this, but, undefeated, hermes, hostels,
# Nearest to the: its, their, this, a, any, your, these, his,
# Nearest to so: geographically, too, thus, if, bullet, pump, rit, sometimes,
# Nearest to b: d, r, c, x, n, l, mobilizing, e,
# Nearest to world: u, ignacio, bromwich, referenda, overturning, sowed, plaques, earth,
# Nearest to no: any, little, tsing, regan, only, meritocratic, cough, modi,
# Nearest to s: rex, feasts, tk, slingshot, whose, morpheus, harburg, freeciv,
# Nearest to would: will, could, may, can, might, must, should, cannot,
# Nearest to but: however, although, which, and, that, still, though, than,
# Nearest to two: three, four, six, seven, five, one, eight, zero,
# Nearest to at: during, on, rabid, near, within, in, unto, under,
# Nearest to one: six, two, seven, four, eight, nine, three, five,
# Nearest to an: transgender, placate, sacagawea, idolatry, diagnoses, the, poured, payroll,
# Nearest to their: its, his, her, the, your, our, insecticides, these,
# Nearest to on: upon, through, within, in, against, at, reveal, about,
# Average loss at step 72000: 3.372371
# Average loss at step 74000: 3.349894
# Average loss at step 76000: 3.319188
# Average loss at step 78000: 3.352588
# Average loss at step 80000: 3.378596
# Nearest to first: second, last, next, third, same, final, original, only,
# Nearest to that: which, however, where, hostels, what, predictability, this, but,
# Nearest to the: its, his, their, a, this, wirth, her, leech,
# Nearest to so: too, geographically, pump, thus, jamiroquai, if, rocked, before,
# Nearest to b: d, c, r, x, k, y, m, f,
# Nearest to world: u, referenda, bromwich, mays, heroic, fante, ii, afc,
# Nearest to no: any, little, regan, tsing, dido, fortress, raucous, ever,
# Nearest to s: harburg, beelzebub, rgermeister, biometric, reilly, buteo, morava, defection,
# Nearest to would: could, will, may, can, might, must, should, did,
# Nearest to but: however, although, and, though, while, than, or, porky,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to at: on, within, during, near, sothoth, polos, in, caddy,
# Nearest to one: six, seven, two, four, eight, three, five, nine,
# Nearest to an: transgender, poured, chinatown, payroll, driven, idolatry, dorsey, presheaf,
# Nearest to their: its, his, her, your, our, the, whose, my,
# Nearest to on: upon, in, through, within, at, conjunctivitis, against, mundi,
# Average loss at step 82000: 3.409290
# Average loss at step 84000: 3.412013
# Average loss at step 86000: 3.389967
# Average loss at step 88000: 3.354199
# Average loss at step 90000: 3.366920
# Nearest to first: second, last, next, third, original, same, final, originally,
# Nearest to that: which, however, what, but, who, hostels, where, shine,
# Nearest to the: its, his, their, your, this, a, any, wirth,
# Nearest to so: too, thus, geographically, before, jamiroquai, constraint, rocked, pump,
# Nearest to b: d, c, r, k, y, l, excavating, gokturk,
# Nearest to world: referenda, bromwich, panasonic, ovulation, winter, earth, odi, fante,
# Nearest to no: little, any, only, always, dido, nn, regan, tripping,
# Nearest to s: his, whose, militarism, endosymbiont, our, generalisations, tasmanian, buteo,
# Nearest to would: will, could, may, can, might, should, must, did,
# Nearest to but: however, although, and, though, while, which, that, lanthanum,
# Nearest to two: three, four, five, seven, six, eight, one, nine,
# Nearest to at: near, during, under, within, before, sothoth, after, on,
# Nearest to one: four, seven, eight, two, six, five, three, nine,
# Nearest to an: another, transgender, graduates, poured, softening, chinatown, diagnoses, bernard,
# Nearest to their: its, his, her, your, our, whose, the, some,
# Nearest to on: upon, against, at, in, konqueror, under, featuring, deteriorating,
# Average loss at step 92000: 3.400340
# Average loss at step 94000: 3.254966
# Average loss at step 96000: 3.357537
# Average loss at step 98000: 3.244383
# Average loss at step 100000: 3.355388
# Nearest to first: last, second, next, third, final, original, same, latter,
# Nearest to that: which, however, what, who, but, hostels, because, undefeated,
# Nearest to the: its, your, his, their, a, our, landmine, each,
# Nearest to so: thus, too, then, jamiroquai, if, geographically, when, bullet,
# Nearest to b: d, c, smiths, projection, r, cken, anubis, eds,
# Nearest to world: referenda, bromwich, u, panasonic, winter, ignacio, sowed, carbides,
# Nearest to no: little, any, only, always, meritocratic, imperfections, breakthrough, vesicles,
# Nearest to s: whose, his, ifrcs, hyde, harburg, landmine, beware, lied,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to but: although, however, and, though, which, while, yet, that,
# Nearest to two: four, three, six, five, seven, eight, one, nine,
# Nearest to at: in, during, within, on, near, under, after, revue,
# Nearest to one: two, seven, four, five, six, eight, nine, three,
# Nearest to an: another, transgender, diagnoses, payroll, tir, witted, poured, graduates,
# Nearest to their: its, his, her, your, our, the, some, whose,
# Nearest to on: upon, in, within, against, through, at, fda, around,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
